# %%
import pandas as pd
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

import requests

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_sovereign_states_by_research_and_development_spending')

# %%
len(tables)
# Out:
# 4

# %%
true_table = tables[1]

# %%
tables[1]
# Out:
#                   Country                                WB[7]          \
#                   Country Research and development expenditure
#                   Country                             % of GDP    Year
# 0                  Angola                                0.03%  2016.0
# 1                 Albania                                0.15%  2008.0
# 2    United Arab Emirates                                1.50%  2021.0
# 3               Argentina                                0.52%  2021.0
# 4                 Armenia                                0.21%  2022.0
# ..                    ...                                  ...     ...
# 148               Vietnam                                0.43%  2021.0
# 149          South Africa                                0.60%  2020.0
# 150                Zambia                                0.28%  2008.0
# 151        European Union                                  NaN     NaN
# ...

# %%
true_table = true_table.iloc[:, :-6]
# Out:
#                 Country                                WB[7]
#                 Country Research and development expenditure
#                 Country                             % of GDP
# 0                Angola                                0.03%
# 1               Albania                                0.15%
# 2  United Arab Emirates                                1.50%
# 3             Argentina                                0.52%
# 4               Armenia                                0.21%

# %%
true_table.columns = true_table.columns.get_level_values(0)

# %%
true_table = true_table.rename(columns={'WB[7]': 'GDP Share'})

# %%
true_table['GDP Share'] = true_table['GDP Share'].str.rstrip('%')

# %%
true_table.to_csv('CC5_Data.csv', index=False)
